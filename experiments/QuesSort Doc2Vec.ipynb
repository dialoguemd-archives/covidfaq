# %% [markdown]
# # Questions Clustering
#
# ## Expected
# Questions to be sorted out such that the response to the whole cluster is samel.
#
# <!--### To Do-->
# Author: Sunanda Bansal
# Organization: Dataperformers
# Date: 24 Mar, 2020 (Start)

# %%
import re
import os
import csv
import sys
import json
import time
import scipy
import socket
import pickle
import numpy as np
import pandas as pd
import multiprocessing as mp

from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import Normalizer   
from sklearn import metrics   
from sklearn.metrics import confusion_matrix
# from sklearn.metrics.pairwise import paired_distances as sklearn_paired_distances

# Plotting
import seaborn as sn
import matplotlib.pyplot as plt

# importing personal development helper classes
import utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Define variables here
#
# Mostly the code will be intended to use with arguments that can be passed in comman line, but jupyter notebook doesn't handle `argparse` well, so the Args class is a temporary way to write the code assumming the variables to be an attribute of an object.

# %%
class Args:
    def __init__(self):
        # The very big scraped file, give absolute path, outside the repo
        self.dataset = "data/train_set_covid.csv"
        self.vector_size = 100
        self.window = 5
        self.max_vocab_size=None
        self.min_count = 5
        self.repr_method = "doc2vec"
args=Args()

# %%
# Disable (FALSE) displaying warnings from the OpenMP* run-time library during program execution.
os.environ['KMP_WARNINGS'] = "FALSE"

# %% [markdown]
# ## Reading Dataset

# %%
dataset = pd.read_csv(args.dataset)

# %%
dataset.head()
# Out:
#              timestamp_est                          anonymous_id language  \
# 0  2020-03-22 10:55:35.958  dfc284f8-e162-44fe-b6ab-4dc25083293e       es
# 1  2020-03-21 22:41:05.702  7a8ef480-4e63-429e-b7ff-4763ad47cfe2       pt
# 2  2020-03-22 20:44:40.577  b3923f7c-ea90-4af2-94c5-5ee8736975fd       ko
# 3  2020-03-21 23:21:56.689  8e750805-9fc2-4702-a244-0b7e67cf29ad       vi
# 4  2020-03-22 11:24:07.614  7977f4b9-e495-45f7-a5ca-841359f618ac       es
#
#                                 question
# 0                          Are you sick?
# 1      When should I go to the hospital?
# 2  I think I have a fever. What do I do?
# 3                                    1+1
# 4                        What's covid19?

# %% [markdown]
# ## Preprocess

# %%
# Will add later, right now, leaving it to the utils doc2vec

# %%
def detect_lang(text):
    try:
        return detect(text)
    except:
        return "unidentifiable"

# %%
from langdetect import detect
dataset["detected_lang"] = dataset.question.apply(detect_lang)

# %%
dataset = dataset[dataset.detected_lang == "en"]

# %% [markdown]
# ## Doc2Vec

# %%
model = utils.text.representation.Doc2Vec(args).initialize(data = [dataset.question])
# Out:
# Training Doc2Vec with 684 Texts

# %%
dataset["embedding"] = model.generate_embedding(dataset.question, returnarray=False)

# %% [markdown]
# ### Kmeans

# %%
kmeans = KMeans(n_clusters=8, random_state=0).fit(list(dataset["embedding"]))

# %%
dataset["cluster_label"] = list(kmeans.labels_)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 4.88135032e-04,  2.15189368e-03,  1.02763379e-03,
#          4.48831823e-04, -7.63452030e-04,  1.45894114e-03,
#         -6.24127861e-04,  3.91772995e-03,  4.63662762e-03,
#         -1.16558478e-03,  2.91725039e-03,  2.88949203e-04,
#          6.80445635e-04,  4.25596628e-03, -4.28963965e-03,
#         -4.12870711e-03, -4.79781581e-03,  3.32619855e-03,
#          2.78156740e-03,  3.70012154e-03,  4.78618359e-03,
#          2.99158553e-03, -3.85206367e-04,  2.80529168e-03,
#         -3.81725584e-03,  1.39921019e-03, -3.56646720e-03,
#          4.44668904e-03,  2.18483212e-04, -8.53380596e-04,
#         -2.35444377e-03,  2.74233683e-03, -4.38496674e-04,
#          6.84339495e-04, -4.81210183e-03,  1.17635494e-03,
#          1.12095720e-03,  1.16933999e-03,  4.43748059e-03,
#          1.81820302e-03, -1.40492094e-03, -6.29680464e-04,
#          1.97631191e-03, -4.39774524e-03,  1.66766718e-03,
#          1.70637865e-03, -2.89617432e-03, -3.71073699e-03,
#         -1.84571650e-03, -1.36289233e-03,  7.01967685e-04,
#         -6.13984885e-04,  4.88373823e-03, -3.97955207e-03,
#         -2.91123241e-03, -3.38690472e-03,  1.53108325e-03,
#         -2.46708398e-03, -3.36892263e-04, -2.55574402e-03,
#         -3.41030420e-03, -3.89624853e-03,  1.56329584e-03,
#         -3.61817051e-03, -3.03417630e-03, -1.31274830e-03,
#          3.08288438e-04, -1.23352717e-03, -2.10729841e-04,
#         -5.14165251e-04, -3.01280297e-04, -8.76318450e-04,
#          7.08856632e-04, -8.26751060e-06, -5.34247713e-04,
#         -4.17154368e-04, -7.03026987e-04, -9.17543713e-04,
#         -2.01913704e-04,  1.09399200e-04, -4.62402040e-04,
#          5.49510285e-04, -4.10924669e-04, -1.04682282e-04,
#         -3.22220118e-04,  2.55430355e-04, -5.17106149e-04,
#         -8.21722087e-04]])

# %%
dataset.sort_values("cluster_label")

# %%
clustered = dataset.reset_index().pivot(index="index",columns="cluster_label", values="question").fillna("-")

# %%
pd.DataFrame(dataset.groupby("ahc_label")["question"].apply(list).values.tolist()).T

# %%
clustered.to_csv("output/clustered.csv")

# %% [markdown]
# ### Agglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
X = pd.DataFrame(dataset["embedding"].values.tolist(), index= dataset.index).to_numpy()
clustering = AgglomerativeClustering(n_clusters=None, compute_full_tree=True, distance_threshold=0.12).fit(X)
dataset["ahc_label"] = clustering.labels_

# dataset.sort_values("ahc_label")[["question","ahc_label"]]

# %%
dataset.groupby("ahc_label").count()
# Out:
#            timestamp_est  anonymous_id  language  question  detected_lang  \
# ahc_label
# 0                    640           640       640       640            640
# 1                     27            27        27        27             27
# 2                     23            23        23        23             23
#
#            embedding
# ahc_label
# 0                640
# 1                 27
# 2                 23

# %%
for label in dataset.ahc_label.unique():
    print(dataset[dataset.ahc_label==label][:10].question)

# %%
dataset.sort_values("ahc_label")[["question","ahc_label"]].to_csv("output/doc2vec_ahc.csv")

# %%
dataset.reset_index().pivot(index="index",columns="ahc_label", values="question").fillna("-").to_csv("output/doc2vec_ahc_cluster_view.csv")

# %%
dataset_2 = dataset[dataset.ahc_label == 0]

# %%
X = pd.DataFrame(dataset_2["embedding"].values.tolist(), index= dataset_2.index).to_numpy()
# lv2 threshold backup 0.061
clustering = AgglomerativeClustering(n_clusters=None, compute_full_tree=True, distance_threshold=0.055).fit(X)
dataset_2["ahc_label_lv2"] = clustering.labels_
# dataset_2.sort_values("ahc_label_lv2")[["question","ahc_label_lv2"]].head()
dataset_2.groupby("ahc_label_lv2")["question"].count().sort_values()

# %%
dataset_2.sort_values("ahc_label_lv2")

# %%
group_counts = dataset_2.groupby("ahc_label_lv2")["question"].count().sort_values().to_frame(name="count")

# %%
# dataset_2.join(group_counts, on="ahc_label_lv2").sort_values(["count","ahc_label_lv2"],ascending=True)[["question","ahc_label","ahc_label_lv2"]].to_csv("output/doc2vec_ahc_lv2.csv")

# %%
dataset_2.reset_index().pivot(index="index",columns="ahc_label_lv2", values="question").fillna("-")

# %%
temp = dataset_2.join(group_counts, on="ahc_label_lv2").sort_values(["count","ahc_label_lv2"],ascending=True)[["question","ahc_label","ahc_label_lv2","count"]]

# %%
temp.head()
# Out:
#                                          question  ahc_label  ahc_label_lv2  \
# 213                          How does it spread ?          0             20
# 284                     How does COVID-19 spread?          0             20
# 1055                    How does Covid-19 spread?          0             20
# 619   What is the incubation period for COVID-19?          0             27
# 659                What’s the incubation period?           0             27
#
#       count
# 213       3
# 284       3
# 1055      3
# 619       3
# 659       3

# %%
dataset = dataset.join(temp["ahc_label_lv2"])
dataset["ahc_label_lv2"] = dataset["ahc_label_lv2"].fillna(value=0)

# %%
dataset.head()
# Out:
#              timestamp_est                          anonymous_id language  \
# 0  2020-03-22 10:55:35.958  dfc284f8-e162-44fe-b6ab-4dc25083293e       es
# 1  2020-03-21 22:41:05.702  7a8ef480-4e63-429e-b7ff-4763ad47cfe2       pt
# 2  2020-03-22 20:44:40.577  b3923f7c-ea90-4af2-94c5-5ee8736975fd       ko
# 4  2020-03-22 11:24:07.614  7977f4b9-e495-45f7-a5ca-841359f618ac       es
# 5  2020-03-22 16:34:39.551  4b388591-5ea5-401f-b387-9a4e6be70a91       pt
#
#                                 question detected_lang  \
# 0                          Are you sick?            en
# 1      When should I go to the hospital?            en
# 2  I think I have a fever. What do I do?            en
# 4                        What's covid19?            en
# 5         Does the virus spread by rain?            en
#
#                                            embedding  ahc_label  ahc_label_lv2
# 0  [0.003665695, -0.0012658612, -0.004298671, 0.0...          0            8.0
# 1  [0.004421982, -0.0015855284, 1.4623756e-05, -0...          0           28.0
# 2  [2.2750562e-05, -0.004664215, -0.0045801885, -...          0            4.0
# 4  [-0.004842487, -0.0034736327, 0.00083430874, 0...          0           32.0
# 5  [-0.0015365956, 0.0011491243, 0.0013140386, -0...          0           11.0

# %%
group_counts = dataset.groupby(["ahc_label","ahc_label_lv2"])["question"].count().sort_values().to_frame(name="count")

# %%
dataset.join(group_counts, on=["ahc_label","ahc_label_lv2"]).sort_values(["count","ahc_label_lv2"],ascending=True)[["question","ahc_label","ahc_label_lv2"]].to_csv("output/doc2vec_ahc_lv2.csv")

# %%
dataset.groupby(["ahc_label","ahc_label_lv2"]).count()

# %% [markdown]
# # Level 2 with Rules Based

# %%
dataset = pd.read_csv("output/text_rules_based_lv2.csv").fillna("unclassified")
dataset = dataset[["question", "cluster"]]
d = dataset[dataset.cluster=="unclassified"]
d.head()
# Out:
#                                             question       cluster
# 0  Are research fundings going to be cut as a res...  unclassified
# 1            Is it ok to go outside to get fresh air  unclassified
# 2  Should I star home and even avoid going to the...  unclassified
# 3           Are we going to have trouble buying milk  unclassified
# 4  Will Covid19 go away like the 1918 influenza a...  unclassified

# %%
model = utils.text.representation.Doc2Vec(args).initialize(data = [d.question])
d["embedding"] = model.generate_embedding(d.question, returnarray=False)
# Out:
# Training Doc2Vec with 250 Texts
# /home/designer1/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
X = pd.DataFrame(d["embedding"].values.tolist(), index= d.index).to_numpy()
clustering = AgglomerativeClustering(n_clusters=None, compute_full_tree=True, distance_threshold=0.05).fit(X)
d["ahc_label"] = clustering.labels_

# Misc.
args.n_clusters = len(d["ahc_label"].unique())
print(f"Found {args.n_clusters} clusters")
d.groupby("ahc_label")["question"].count().sort_values()
# Out:
# Found 32 clusters
# /home/designer1/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# ahc_label
# 28     2
# 21     2
# 17     2
# 15     4
# 27     4
# 23     4
# 30     4
# 20     5
# 0      6
# 31     7
# 26     7
# 24     7
# 22     7
# 10     8
# 11     8
# 29     8
# 13     8
# 25     8
# 4      9
# 5      9
# 16     9
# 18    10
# 3     10
# 7     10
# 14    10
# 12    10
# 19    10
# 1     11
# 8     12
# 2     12
# 9     12
# 6     15
# Name: question, dtype: int64

# %%
for label in d.ahc_label.unique():
    print(f"cluster #{label}, count - {len(d[d.ahc_label==label])}")
    print(d[d.ahc_label==label][:10].question)
# Out:
# cluster #24, count - 7
# 0      Are research fundings going to be cut as a res...
# 17     Is it true that COVID 19 can survive up to a f...
# 143    Will the heat of the summer help fighting the ...
# 152            What are the best food to get good immune
# 214    Does washing clothes in the washing machine pr...
# 303               How often should i take my temperature
# 331                        Why is it called Corona virus
# Name: question, dtype: object
# cluster #6, count - 15
# 1                Is it ok to go outside to get fresh air
# 8                                           how is going
# 27     Will herd immunity be the only means of eradic...
# 91                                   Is the virus deadly
# 94                           How did this virus transmit
# 107                                How is it transmitted
# 145                                     I think I m sick
# 193                     is it made by human or by nature
# 232    What s the point of asking you questions if yo...
# 266                             Is ACE Inhibitor harmful
# Name: question, dtype: object
# cluster #2, count - 12
# 2      Should I star home and even avoid going to the...
# 16         How can I differ between covid and normal flu
# 23      How should I keep my family safe during covid 19
# 76     Would it help to ensure there is a warehouse a...
# 101                                Is the virus airborne
# 178              Why didn t you answer my first question
# 211    Sorry I het enter before I was done am I just ...
# 222                                        mental health
# 249               When do I expect to hear back from you
# 265                         When will we be back to work
# Name: question, dtype: object
# cluster #22, count - 7
# 3               Are we going to have trouble buying milk
# 100                      Does soap really kill the virus
# 200                                        Impacts of it
# 228    When will the municipalities post heat maps to...
# 231                           What is the mortality rate
# 320                     What is the probability of dying
# 334                  is there a new form of corona virus
# Name: question, dtype: object
# cluster #11, count - 8
# 4      Will Covid19 go away like the 1918 influenza a...
# 7                             When should I go to the ER
# 97                                 Has the virus evolved
# 109      Can this virus infect me in an airborne fashion
# 218                               Is Covid19 an airborne
# 225         Have there been any deceased children so far
# 233                  How much it s prevelent in Pakistan
# 318    Will people on LTD Long Term Disability drill ...
# Name: question, dtype: object
# cluster #19, count - 10
# 5                             Where should I go
# 33            What places of laval has covid 19
# 137                 Do you think Taiwan is good
# 138                         is the grocery open
# 150                Will the groceries shut down
# 209           Will there be any changes in PGWP
# 236                              how to prevent
# 252    Option to run the questions for children
# 309                            Do I need a mask
# 313        How many thing you do not understand
# Name: question, dtype: object
# cluster #12, count - 10
# 6                         when covid 19 is going to stop
# 30     What are the side effects of hydroxychloroquin...
# 59                         how many people die for cover
# 140    What should I use to disinfect grocery bags an...
# 189                                             Can I fo
# 238                                         Hypertension
# 248                              How i know that i m ill
# 283        Is the phlegm color suggestive of coronavirus
# 323    Shall we stay where we are or travel to our ho...
# 330                      Hello what happens after corona
# Name: question, dtype: object
# cluster #13, count - 8
# 9                          Am I allowed to go for a walk
# 12             Is there more than one strain of COVID 19
# 92     If I inhale a high concentration of soap bubbl...
# 251                           Should I not touch my mail
# 284                           How do I treat coronavirus
# 335       What the different between corona and COVID_19
# 338           How long will I be sick if I get the virus
# 357                   My brother has COVID 19 What to do
# Name: question, dtype: object
# cluster #14, count - 10
# 10                      When will it be ok to go outside
# 61                               Can I die from Covid 19
# 96     Isn t the economy impact and the panic reactio...
# 206                           Can I still see my friends
# 237                                why is my dick so big
# 260                                How to avoid exposure
# 305    Is it true that you can get the virus again ev...
# 310    Why does the government think that we don t ne...
# 351    Once you are cured from Covid 19 can you catch...
# 358                      what do you know about COVID 19
# Name: question, dtype: object
# cluster #1, count - 11
# 11     how much fever should i tolerate before going ...
# 22     How can I make sure I am buying from grocery i...
# 95     Is the virus vulnerable to high temperature Do...
# 106                             How is covid transmitted
# 153    How long does the virus stay in paper money an...
# 159    If you contract COVID 19 how do you treat your...
# 240    Could stores open a few hours a week for the e...
# 250    My father is 80 years and food is delivered to...
# 267                 what is canada s situation right now
# 296                                   where did it start
# Name: question, dtype: object
# cluster #5, count - 9
# 13     How does COVID 19 affect lungs And how do you ...
# 151    Do I need to disinfect things I buy like groce...
# 235                              what is self monitoring
# 241                        Is it safe to jog run outside
# 254    waht are thenoptiin to disinfect hands and sur...
# 317    How do we best organize people so that duplica...
# 324                             Do the virus stay in air
# 349                 How to know if I get COVID 19 or not
# 356                            How COVID 19 is infecting
# Name: question, dtype: object
# cluster #4, count - 9
# 14                                       Impact of covid
# 35                      Is itchy throat sign of covid 19
# 134    Should I be worried about getting sick if the ...
# 184    How do I know if my chest is hurt because lung...
# 201          Should I visit my parents in a seniors home
# 215                                 Mortality rate today
# 306    What measures can I take if someone I know is ...
# 337                         Corona virus characteristics
# 347                        should I worry about covid 19
# Name: question, dtype: object
# cluster #8, count - 12
# 15                      age wise statistics for covid 19
# 21                            How about covid situations
# 99               Will the virus affect my sexual ability
# 103                              How severe is the virus
# 133                             Does Wearing gloves help
# 197    I recently relocated to Quebec Can I request R...
# 198    hat should I do if my 2 year old child starts ...
# 203                 Is it transmissible through anal sex
# 229              What is the situation now in my country
# 285    Can anti viral drugs be used to treat the coro...
# Name: question, dtype: object
# cluster #27, count - 4
# 18     How effective is the new drug manufactured by ...
# 219                                        What the size
# 239                        How s the shortness of breath
# 246                                      how old are you
# Name: question, dtype: object
# cluster #18, count - 10
# 19                    How does COVID 19 kill its victims
# 93                            When this virus terminated
# 110                          how can one fight the virus
# 146    Are there any federal or provincial services t...
# 157                     Can the Covid survive in the air
# 183                      im sneezing should i be worried
# 186                                               Chlono
# 192                                          South korea
# 257                                                  Non
# 286    How to differentiate between coronavirus and s...
# Name: question, dtype: object
# cluster #0, count - 6
# 20     Is it safe to order food during the COVID 19 p...
# 224                                    what is this site
# 242                           Are vet clinics still open
# 256                            could we have done better
# 262    How can I make the difference between a cold a...
# 269    Who can I make the difference between a cold a...
# Name: question, dtype: object
# cluster #25, count - 8
# 24     My head hurts my body aches a little and I fee...
# 158    How long could the virus stay alive on doorkno...
# 191                         Where can we find ventilator
# 196                         Will 1 meter distancing safe
# 204                                              Covid19
# 207                      What s the capital of Palestine
# 216                     what is canada quarantine policy
# 329               How long can the virus stay in the air
# Name: question, dtype: object
# cluster #20, count - 5
# 25                   Can you smoke cannabis during Covid
# 144           Do I need to wash my vegetables and fruits
# 147    Is it safe to get a new job that deals with th...
# 332              how to know that somebody have a corona
# 333                    Does the fever persists in corona
# Name: question, dtype: object
# cluster #7, count - 10
# 26          Will the pandemic affect university research
# 156                      Does covid transfer through air
# 180    What s happen for country near the Ecuador wit...
# 182                     As of today can we gather only 2
# 208    If this is really deep learning how deep is yo...
# 217                             is the liquor store open
# 220       I worry for my mental health during quarantine
# 268                                Why is Trudeau asleep
# 288    How do I distinguish between the flu and coron...
# 355                              How can i cure covid 19
# Name: question, dtype: object
# cluster #29, count - 8
# 28                                       Define covid 18
# 84     How long does the virus remain active and aliv...
# 135                    When will life get back to normal
# 261    What should you do if you dont have water and ...
# 264    In this time of crisis is it okay to feed the ...
# 308                                   Should I wear mask
# 322    How many will lose their jobs due to the chine...
# 342                 Can I get the virus from a stray cat
# Name: question, dtype: object
# cluster #10, count - 8
# 29     Would using heated vapor humidifier help with ...
# 112    Do we see a future where this virus won t be s...
# 132                                     where can I help
# 154    Can COVID 19 stay alive on fresh fruit and veg...
# 202                     when will germany reach the peak
# 226             What should i do if i am short of breath
# 298    If you recover from the virus can you still be...
# 353                              What colour is covid 19
# Name: question, dtype: object
# cluster #26, count - 7
# 31                          How do i knew if i got covid
# 36     It would possible to predict the time of this ...
# 142    Does eating Oranges daily help to fight this v...
# 181    Will the largest commercial suppliers in the c...
# 185     What will be th impact on international students
# 247    What is the advice surrounding outdoor exercis...
# 345                               Why is called COVID 19
# Name: question, dtype: object
# cluster #15, count - 4
# 32                                Infomation about covid
# 90     If I cross someone on the street how are the c...
# 195         What is the situation right now in the world
# 307       Is it useful to wear a mask if we are not sick
# Name: question, dtype: object
# cluster #3, count - 10
# 34            Should I be moving house during a pandemic
# 55                    Can you die from contracting covid
# 58                   In how many days can covid be cured
# 104         Does temperature has any effect on the virus
# 111    What is the difference between a bacteria and ...
# 136                                 Should I use Sudafed
# 139                     Do I need to be seen by a doctor
# 148    Will it get better in summer with higher tempe...
# 210                Are there still flights within Canada
# 341    If I catch the virus will I be immune from get...
# Name: question, dtype: object
# cluster #16, count - 9
# 89     How long are you contagious if you have Corona...
# 188                         When will the schools reopen
# 205                                   what has caused it
# 227                         When should I visit a doctor
# 244                       When should I contact a doctor
# 255                                    When will be done
# 258                                         good morning
# 312    what is this rainbow thing that people are tal...
# 326                      Does the virus stay on clothing
# Name: question, dtype: object
# cluster #28, count - 2
# 98     How deadly is the virus
# 108    How deadly is the virus
# Name: question, dtype: object
# cluster #9, count - 12
# 102            how painful will it be if I got the virus
# 141    What should I buy from the stores now that I f...
# 149    What have you implemented to help older people...
# 155    how much does corona virus stay on each kind o...
# 160                                Is COVID 19 air borne
# 199       Is ordering food from a restaurant discouraged
# 221                               Precautions to measure
# 245                 What are effective immunity boosters
# 339                          Can you get the virus twice
# 340                             Can my cat get the virus
# Name: question, dtype: object
# cluster #30, count - 4
# 105                          How contagious is the virus
# 212    My son is flying from Kansas to England on the...
# 223                        Suffering from trout echiting
# 243                             Is it safe to give blood
# Name: question, dtype: object
# cluster #31, count - 7
# 187    What should I do
# 194             What is
# 213         How are you
# 230          What is it
# 234         How are you
# 253      who can you do
# 263         how are you
# Name: question, dtype: object
# cluster #17, count - 2
# 190    What is your name
# 259    WHat is your name
# Name: question, dtype: object
# cluster #23, count - 4
# 282               Is it true that warm kills Coronavirus
# 287               Is it true that warm kills Coronavirus
# 299              Is there any medication to take to help
# 348    Can you catch covid 19 after having had it before
# Name: question, dtype: object
# cluster #21, count - 2
# 344    COVID 19 stands for what
# 359    What COVID 19 stands for
# Name: question, dtype: object
