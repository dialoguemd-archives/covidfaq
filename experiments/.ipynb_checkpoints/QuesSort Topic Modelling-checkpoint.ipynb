# %% [markdown]
# # Questions Clustering
#
# ## Expected
# Questions to be sorted out such that the response to the whole cluster is samel.
#
# <!--### To Do-->
# Author: Sunanda Bansal
# Organization: Dataperformers
# Date: 24 Mar, 2020 (Start)

# %%
import re
import os
import csv
import sys
import json
import time
import scipy
import socket
import pickle
import numpy as np
import pandas as pd
import multiprocessing as mp

from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import Normalizer   
from sklearn import metrics   
from sklearn.metrics import confusion_matrix
# from sklearn.metrics.pairwise import paired_distances as sklearn_paired_distances

# Plotting
import seaborn as sn
import matplotlib.pyplot as plt

# importing personal development helper classes
import utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Define variables here
#
# Mostly the code will be intended to use with arguments that can be passed in comman line, but jupyter notebook doesn't handle `argparse` well, so the Args class is a temporary way to write the code assumming the variables to be an attribute of an object.

# %%
class Args:
    def __init__(self):
        # The very big scraped file, give absolute path, outside the repo
        self.dataset = "data/train_set_covid.csv"
        self.vector_mode = "tfidf"
        self.n_topics = 15
        self.repr_method = "lsi"
args=Args()

# %%
# Disable (FALSE) displaying warnings from the OpenMP* run-time library during program execution.
os.environ['KMP_WARNINGS'] = "FALSE"

# %% [markdown]
# ## Reading Dataset

# %%
dataset = pd.read_csv(args.dataset)

# %%
dataset.head()
# Out:
#              timestamp_est                          anonymous_id language  \
# 0  2020-03-22 10:55:35.958  dfc284f8-e162-44fe-b6ab-4dc25083293e       es
# 1  2020-03-21 22:41:05.702  7a8ef480-4e63-429e-b7ff-4763ad47cfe2       pt
# 2  2020-03-22 20:44:40.577  b3923f7c-ea90-4af2-94c5-5ee8736975fd       ko
# 3  2020-03-21 23:21:56.689  8e750805-9fc2-4702-a244-0b7e67cf29ad       vi
# 4  2020-03-22 11:24:07.614  7977f4b9-e495-45f7-a5ca-841359f618ac       es
#
#                                 question
# 0                          Are you sick?
# 1      When should I go to the hospital?
# 2  I think I have a fever. What do I do?
# 3                                    1+1
# 4                        What's covid19?

# %% [markdown]
# ## Preprocess

# %%
# Will add later, right now, leaving it to the utils doc2vec

# %%
def detect_lang(text):
    try:
        return detect(text)
    except:
        return "unidentifiable"

# %%
from langdetect import detect
dataset["detected_lang"] = dataset.question.apply(detect_lang)

# %%
dataset = dataset[dataset.detected_lang == "en"]

# %%
import re
regex = re.compile('[^a-zA-Z]')

from nltk.corpus import stopwords as sw
stopwords = sw.words('english')

from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

def tokenize(text):
    tokens = []
    for sent in nltk.sent_tokenize(text):
        for word in nltk.word_tokenize(sent):
            clean_word = regex.sub('', word)
            tokens.append(clean_word.lower())
    return tokens


def stem(word):
    return stemmer.stem(word).strip()


# def preprocess(text):    
#     tokenized = tokenize(text)
#     cleaned = [word for word in tokenized if word not in stopwords and word is not '']
#     stemed = [stem(word) for word in cleaned]
#     #stemed = [stem(word) for word in tokenized]
#     #corpus[i] = ' '.join(tokenized)
#     return ' '.join(stemed)

# %%
# import nltk

# dataset["cleaned_question"] = dataset.question.apply(preprocess)

# %%
dataset.head()
# Out:
#              timestamp_est                          anonymous_id language  \
# 0  2020-03-22 10:55:35.958  dfc284f8-e162-44fe-b6ab-4dc25083293e       es
# 1  2020-03-21 22:41:05.702  7a8ef480-4e63-429e-b7ff-4763ad47cfe2       pt
# 2  2020-03-22 20:44:40.577  b3923f7c-ea90-4af2-94c5-5ee8736975fd       ko
# 4  2020-03-22 11:24:07.614  7977f4b9-e495-45f7-a5ca-841359f618ac       es
# 5  2020-03-22 16:34:39.551  4b388591-5ea5-401f-b387-9a4e6be70a91       pt
#
#                                 question detected_lang
# 0                          Are you sick?            en
# 1      When should I go to the hospital?            en
# 2  I think I have a fever. What do I do?            en
# 4                        What's covid19?            en
# 5         Does the virus spread by rain?            en

# %%
# import nltk
# from sklearn.feature_extraction.text import TfidfVectorizer

# tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=5000,
#                                  min_df=0.05, stop_words="english",
#                                  use_idf=True, tokenizer=tokenize,
#                                   lowercase=True)

# tfidf_matrix = tfidf_vectorizer.fit_transform(dataset.question)

# %% [markdown]
# ## LSI

# %%
model = utils.text.representation.LSI(args)

# %%
results = model.plot_graph(dataset.question,600,1000,5)

# %%
results_300_600_5 = results

# %%
pickle.dump(results_300_600_5,open("output/pickle/lsa_coherence_300_600_5.p","wb"))

# %%
# model.plot_graph(dataset.question,5,8,1)

# %%
results

# %%
args.n_topics = 230

# %%
dataset["embedding"] = model.generate_embedding(dataset.question, returnarray=False)

# %% [markdown]
# ## LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation
for n in range(5,30):
    lda = LatentDirichletAllocation(n_components=n, random_state=42)
    lda.fit(tfidf_matrix)
    topic_values = lda.transform(tfidf_matrix)
    dataset[f"lda_{n}n_label"] = topic_values.argmax(axis=1)
    dataset[f"embedding_{n}n"] = list(topic_values)

# %%
lda = LatentDirichletAllocation(n_components=10, random_state=42)
lda.fit(tfidf_matrix)
topic_values = lda.transform(tfidf_matrix)
dataset[f"lda_label"] = topic_values.argmax(axis=1)
dataset[f"embedding"] = list(topic_values)

# %%
dataset.columns[dataset.columns.str.contains("embedding")]

# %%
dataset[["question","lda_15n_label"]].sort_values("lda_15n_label")

# %%
dataset.head()

# %% [markdown]
# ### Kmeans

# %%
for col in dataset.columns[dataset.columns.str.contains("embedding_")]:
    for n in range(5,20):
        kmeans = KMeans(n_clusters=n, random_state=42).fit(list(dataset[col]))
        dataset[f"{n}km_{col.replace('embedding_','')}lda"] = list(kmeans.labels_)
#         dataset.reset_index()\
#                .pivot(index="index",columns=f"kmeans_{n}n_label", values="question")\
#                .fillna("-")\
#                .to_csv(f"output/km_{n}n_lda_{col.replace('embedding_','')}.csv")

# %%
kmeans = KMeans(n_clusters=15, random_state=42).fit(list(dataset["embedding"]))
dataset["kmeans_label"] = list(kmeans.labels_)

# %%
dataset.groupby("kmeans_label").count()

# %%
dataset.sort_values("kmeans_label")

# %%
for label in dataset.kmeans_label.unique():
    print(dataset[dataset.kmeans_label==label][:10].question)

# %%
counts = pd.DataFrame(list(dataset.groupby("kmeans_label")["question"].apply(list))).T.count().to_frame("Count")

# %%
counts.T.append(pd.DataFrame(list(dataset.groupby("kmeans_label")["question"].apply(list))).T.fillna("-")).add_prefix("cluster_#").to_csv("output/clusters_15KMeans_lsa.csv")

# %%
pd.DataFrame(list(dataset.groupby("kmeans_label")["question"].apply(list))).T.fillna("-").add_prefix("cluster_#")

# %% [markdown]
# ### Agglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
X = pd.DataFrame(dataset["embedding"].values.tolist(), index= dataset.index).to_numpy()
clustering = AgglomerativeClustering(n_clusters=None, compute_full_tree=True, distance_threshold=2.7).fit(X)
dataset["ahc_label"] = clustering.labels_
dataset.groupby("ahc_label")["question"].count().sort_values()
# Out:
# ahc_label
# 16      6
# 15      6
# 13      7
# 14      7
# 18      8
# 5       8
# 21      8
# 22     10
# 19     11
# 17     11
# 7      11
# 6      12
# 12     14
# 1      16
# 9      16
# 8      17
# 11     18
# 10     20
# 20     22
# 3      25
# 2      27
# 4      44
# 0     359
# Name: question, dtype: int64

# %%
dataset.groupby("ahc_label")["question"].count().describe()
# Out:
# count     23.000000
# mean      29.695652
# std       72.319641
# min        6.000000
# 25%        8.000000
# 50%       12.000000
# 75%       19.000000
# max      359.000000
# Name: question, dtype: float64

# %%
for label in dataset.ahc_label.unique():
    print(f"\ncluster_#{label}\n-----------")
    print(dataset[dataset.ahc_label==label][:10].question.values)
# Out:
# cluster_#6
# -----------
# ['When should I go to the hospital?' 'how is going' 'Where should I go?'
#  'should I go to the hospital?'
#  "Should I go to the ER or my physician directly if I'm infected?"
#  'When will it be ok to go outside?'
#  'if i have symptoms should i go to the ER or should I call a doctor?'
#  'What is the nearest hospital to go to if I have a COVID-19?'
#  'When should I go to the ER?' 'Is it ok to go outside to get fresh air?']
#
# cluster_#18
# -----------
# ['I think I have a fever. What do I do?'
#  'I think I have coronavirus, should I go to the emergency'
#  'I think I’m sick' "What should I do if i think that i'm infected ?"
#  'I think I have COVID'
#  'How long do you think we will have to be in a lockdown '
#  'what should I do if I think I infected by corona virus?'
#  'What to do if I think I have covid 19?']
#
# cluster_#7
# -----------
# ["What's covid19?" 'What is Covid19'
#  'What are the symptoms of the covid19?' "What's covid19? " 'covid19'
#  'What are the symptoms of covid19' 'What are the symptoms of covid19?'
#  "What's covid19" 'What is covid19?' 'What are the Symptom for covid19']
#
# cluster_#19
# -----------
# ['Does the virus spread by rain?' 'How does it spread ?'
#  'how is covid 19 spread?' 'How does COVID-19 spread?'
#  'what is canada quarantine policy?'
#  'How fast will the pandemic spread in Canada?'
#  'is china responsible for the spreading of COVID-19?'
#  'How does Covid-19 spread?' 'how to prepare for spread of covid 19?'
#  'How long has the virus been spreading in Canada?']
#
# cluster_#0
# -----------
# ['What are the synthoms?'
#  'What mesures needs to take a pregnant women to reduce the risk?'
#  'Do you think Taiwan is good?' 'covid19 symptons?'
#  'Is the Asymptomatic Carrier a temporary status? ' 'What is it'
#  'How to avoid exposure?'
#  'What is the impact that covid-19 has in the economy?' 'South korea'
#  'What is']
#
# cluster_#20
# -----------
# ['what is covid-19' 'What is Covid-19?' 'What is the COVID-19?'
#  "what's is COVID-19?" 'Covid-19' 'What is covid 19?' 'What is COVID 19?'
#  'what is covid-19 ?' 'What is COVID-19' 'Why Covid 19?']
#
# cluster_#5
# -----------
# ["How's the shortness of breath?" 'I have fever what I should do'
#  'Must the fever-symptom related to COVID-19 be a continuous fever, or is it possible that the fever is short-lived?'
#  'is fever a symptom of coronavirus? ' 'What should I do if I have fever?'
#  'I have shortness of breath but no fever'
#  'I have a fever, what should I do now?'
#  'What should i do if i am short of breath?']
#
# cluster_#17
# -----------
# ['How do I know if I haver coronavirus?' 'may I know what is corona?'
#  'what do you know about COVID-19?'
#  'How do I know if I have the corona virus'
#  'How do I know if I have the covid-19' "How i know that i 'm ill"
#  'how to know if i have corona' 'how to know that somebody have a corona'
#  'How do I know I have covid?' 'How do I know if I have been infected?']
#
# cluster_#14
# -----------
# ['What is the covid?' 'What is covid' 'What is covid?' 'What is covid'
#  'Covid?' 'What is covid' 'Do I have covid?']
#
# cluster_#10
# -----------
# ['Which country infected ? ' 'Am I infected'
#  "What do I do if I suspect I'm infected?"
#  'how can I prevent to get infected?' 'Which country infected ? '
#  'Can this virus infect me in an airborne fashion?'
#  'Can you get be infected more than once? ' 'What is Covid-19 virus?)'
#  'how to prevent ?' 'Can I get infected after I healed from it?']
#
# cluster_#12
# -----------
# ['How many people have dies'
#  'who is at risk of dying after contracting the virus?'
#  'how many people died?' 'What is the probability of dying?'
#  'How does it die in asymptomatic people?'
#  'how many people have died in the US?' 'Can I die from Covid-19?'
#  'If you contract COVID-19, how do you treat yourself at home?'
#  'how many people die for cover?' 'How many people died in NYC']
#
# cluster_#3
# -----------
# ['What is coronavirus ?' 'What are the symptoms of vivid 19?'
#  'How can I make the difference between a cold and covid19?'
#  'Why are death rates so different across countries?'
#  'How does coronavirus propagate?'
#  'Is fever the main symptom for vivid-19' 'What are the main synptoms?'
#  'what are the main symptoms'
#  'How can I differ between covid and normal flu ?'
#  'what are the main symptoms of coronavirus']
#
# cluster_#2
# -----------
# ['what are the symptoms' 'what are the symptoms of COVID-19?'
#  'What are the symptoms' 'what are the symptoms' 'What are the symptoms '
#  'What are the symptoms' 'Symptoms of Covid '
#  'What are the symptoms of Covid-19?' 'Symptoms' 'Symptom']
#
# cluster_#4
# -----------
# ['Why Germany has a low death rate?'
#  'How many confirmed cases in Ontario now?' 'How many cases in Quebec? '
#  'How many cases in Montreal?'
#  'How do people get infected with Coronavirus?'
#  'how many people positive result with COVID-19'
#  'how many cases are there in Washington state'
#  'How many people are infected in Lithuania?'
#  'how to interact with people' 'When will the cure be available ?']
#
# cluster_#8
# -----------
# ['Does covid-19 test anonymous?'
#  'Where are the testing centers located in Mtl?'
#  'which hospital takes the test for covid 19?'
#  'Is the test covered in in CIHIP?' 'Where should I be tested ?'
#  'Where is the closest testing facility to me?' 'Where can I get tested?'
#  'where can I test for covid' 'Where do we get the test for COVID-19?'
#  'Were can I get tested? ']
#
# cluster_#9
# -----------
# ['Is there a vaccine for corona virus?'
#  'When will the treatment be available for this pandemic?'
#  'What is a vaccin becoming available?' 'How long is the treatment?'
#  'How long does it take to recover?' 'treatment for covid 19'
#  'How long does it take an average person to recover?'
#  'How long will it take to develop a vaccine ? '
#  'How long will it take for a vaccine to be produced?'
#  'what treatments are available for covid-19?']
#
# cluster_#21
# -----------
# ['Does a throat feel itchy or really sore and a symptom '
#  'Is itchy throat sign of covid 19' 'I have throat '
#  'I am having sore throat, cold, cough, temperature is not stable continuously increases and decreases. So Do I need to go for a test?'
#  'I have a sore throat. What do I do?' 'Is sore throats a symptom '
#  'I am feeling itchy around my body. Is it a symptom of covid? '
#  'I have a sore throat. Is that a sign of Covid19?']
#
# cluster_#1
# -----------
# ['How long are you contagious if you have Coronavirus?'
#  "I'd love to know how long I can be contagious?"
#  'How long before symptoms start to show? ' 'How long does it last? '
#  'How many days can you be contagious without showing symptoms?'
#  'How long does it last once infected ?'
#  'How long until an infected person shows symptoms?'
#  "Can I be contagious even if I don't have symptoms? "
#  'How long will it last?'
#  "Can we be contagious when we don't show symptoms?"]
#
# cluster_#13
# -----------
# ['Is the virus infectious during incubation period?'
#  'What is the incubation period for COVID-19?'
#  'What’s the incubation period? ' 'What is the period of incubation?'
#  'What is the incubation period? ' 'How long is incubation period? '
#  'How long does this virus incubate? ']
#
# cluster_#11
# -----------
# ['what is the death rate of the new corona virus' 'Symptoms of corona'
#  'I have cold for couple of weeks. Have cough over night and regular mucous during day and night. Feel a bit hot but not fever that can be feel. Sometimes ear pain for infection. Some times get stressed on having corona. Does any of these symptoms suggest that? I have quarantined myself for over 10 days  '
#  'Whats corona' 'What are the symptoms of Corona?'
#  'What are the symptoms of corona virus'
#  'Does the fever persists in corona '
#  'I have fever 38°C. Is that corona virus symptoms?'
#  'What is corona virus and COVID19' 'What is corona virus?']
#
# cluster_#15
# -----------
# ['How to protect my family from COVID-19?'
#  'How to protect myself on a plane' 'how to protect myself from it '
#  'How can I protect myself from the covid-19?'
#  'What can we do to protect ourselves from COVID-19?'
#  'How can I protect myself ']
#
# cluster_#22
# -----------
# ['is coughing phlem a symptom?' 'I cough. is it Covid-19?'
#  'What if I have cough ?' 'where did it start' 'How Covid-19 started?'
#  'Is a cough but no fever a symptom?'
#  "I am coughing but I don't have fever. Could I have covid-19?"
#  'i am coughing, what should i do?' 'What to do when i gave cough'
#  'What should I do if I start coughing?']
#
# cluster_#16
# -----------
# ['when is this pandemic going to end?' 'when will the pandemic end?'
#  'When will this end' 'When this will ever end '
#  'When will the pandemic end? ' 'When will covid end? ']

# %%
dataset.sort_values("ahc_label")[["question","ahc_label"]]
# Out:
#                                                question  ahc_label
# 1852  If I cross someone on the street, how are the ...          0
# 1319  Shall we stay where we are or travel to our ho...          0
# 722   Could stores open a few hours a week for the e...          0
# 720   how much does corona virus stay on each kind o...          0
# 1321                           What colour is covid 19?          0
# 1322  Why does the government think that we don't ne...          0
# 1323     How long does COVID-19 live on glass surfaces?          0
# 1327      What is the situation right now in the world?          0
# 710    When should I consult after the vomitting sym...          0
# 727   How long does the virus stay in paper money an...          0
# 709             What are the early symptoms of COVID-19          0
# 702   Will it get better in summer with higher tempe...          0
# 700                  Does COVID 19 cause stomach issues          0
# 1331  How long does it takes to get first symptom of...          0
# 695            How long does the virus live on clothes?          0
# 1333                  What's the current count in India          0
# 687                         Are vet clinics still open?          0
# 683   I need to take a blood test. Is there a large ...          0
# 1334           Why didn't you answer my first question?          0
# 1330                                    Define covid 18          0
# 728   How effective is the new drug manufactured by ...          0
# 1312  Would using heated-vapor humidifier help with ...          0
# 734   If I fully recover from COVID-19 would I still...          0
# 789                               Has the virus evolved          0
# 781   How long can the covid-19 survive outside the ...          0
# 780           Does my neighbour have covid-19 symptoms?          0
# 776                      Why is it called Corona virus?          0
# 1266                                  What is your name          0
# 1267     How long will social distancing measures last?          0
# 1268  If I catch the virus, will I be immune from ge...          0
# ...                                                 ...        ...
# 678               How long does it last once infected ?         25
# 1144                       How long the sickens last, m         25
# 1220                      How many cases are in spain ?         26
# 1489                                 how many new cases         26
# 1487                  What places of laval has covid-19         26
# 186            How many confirmed cases in Ontario now?         26
# 654                           How many case in montreal         26
# 340        how many cases are there in Washington state         26
# 1008                          How many cases in Quebec          26
# 996                         How many cases in Montreal          26
# 1032                   How many cases of covid in laval         26
# 1702        How many cases of coronavirus in Madagascar         26
# 617                          How many cases in Montreal         26
# 289                         How many cases in Montreal?         26
# 218                          How many cases in Quebec?          26
# 909   What is the current COVID-19 confirmed cases t...         26
# 1548         What are the confirmed symptoms of COVID19         26
# 1301                    How many cases in Canada now ?          26
# 1813                       How dangerous is the COV-19?         27
# 1773                          is it dangerous to travel         27
# 952                               is covid-19 dangerous         27
# 557                             Is covid very dangerous         27
# 1743                        Why corona is so dangerous          27
# 619         What is the incubation period for COVID-19?         28
# 1156                    How long is incubation period?          28
# 712                   What is the period of incubation?         28
# 1587                How long does this virus incubate?          28
# 659                      What’s the incubation period?          28
# 233   Is the virus infectious during incubation period?         28
# 714                     What is the incubation period?          28
#
# [683 rows x 2 columns]

# %%
dataset.sort_values("ahc_label")[["question","ahc_label"]].to_csv("output/230lsa_ahc_1.5DT.csv")

# %%
counts = pd.DataFrame(list(dataset.groupby("ahc_label")["question"].apply(list))).T.count().to_frame("Count")

# %%
# pd.DataFrame(list(dataset.groupby("ahc_label")["question"].apply(list))).T.count().add_prefix("cluster_#")

# %%
visual = counts.T.append(pd.DataFrame(list(dataset.groupby("ahc_label")["question"].apply(list))).T.fillna("-")).add_prefix("cluster_#")

# %%
visual.head()
# Out:
#                                           cluster_#0  \
# Count                                              9
# 0                      Does covid-19 test anonymous?
# 1      Where are the testing centers located in Mtl?
# 2        which hospital takes the test for covid 19?
# 3                   Is the test covered in in CIHIP?
#
#                                               cluster_#1  \
# Count                                                  4
# 0      Will it get better in summer with higher tempe...
# 1      Could stores open a few hours a week for the e...
# 2                              is the liquor store open?
# 3                             could we have done better?
#
#                                               cluster_#2  \
# Count                                                  5
# 0      How do we best organize people so that duplica...
# 1      How am I supposed to work while I have two you...
# 2                          When will we be back to work?
# 3      What are the demographics of people infected, ...
#
#                    cluster_#3  \
# Count                      46
# 0      What are the synthoms?
# 1           covid19 symptons?
# 2                  What is it
# 3                     What is
#
#                                               cluster_#4  \
# Count                                                  4
# 0      Can COVID-19 stay alive on fresh fruit and veg...
# 1            Do I need to wash my vegetables and fruits?
# 2      Does washing clothes in the  washing machine p...
# 3                 Is it transmissible through anal sex ?
#
#                                               cluster_#5  \
# Count                                                  5
# 0      Will Covid19 go away like the 1918 influenza a...
# 1      what are the conditions under which people are...
# 2      I would like clarifications about the fact tha...
# 3                    What are the symptoms of SARS-COV-2
#
#                                               cluster_#6  \
# Count                                                 16
# 0      if my tempreture is over 39 can i assume that ...
# 1         What are the most common symptoms of COVID-19?
# 2                What are the early symptoms of COVID-19
# 3                What are the real symptoms of covid-19
#
#                                               cluster_#7  \
# Count                                                  5
# 0      If I’m sneezing, should I get tested for coron...
# 1      If there are kids around me, do I have to worr...
# 2      Should I be worried about getting sick if the ...
# 3                      im sneezing, should i be worried?
#
#                                               cluster_#8  \
# Count                                                  4
# 0                          Where can we find ventilator?
# 1                         Why is it called Corona virus?
# 2                                 Why is called COVID-19
# 3      should I call to find out more, it’s the cough...
#
#                                               cluster_#9  ...  \
# Count                                                  6  ...
# 0                                 How to avoid exposure?  ...
# 1      Should I star home and even avoid going to the...  ...
# 2      Will NHS workers be even more isolated because...  ...
# 3      Is it true that you can get the virus again ev...  ...
#
#                       cluster_#125  \
# Count                            4
# 0      How many cases in Montreal?
# 1       How many cases in Montreal
# 2        How many case in montreal
# 3      How many cases in Montreal
#
#                                             cluster_#126  \
# Count                                                  3
# 0          how many people positive result with COVID-19
# 1                 how many case positive with COVID-19 ?
# 2      how many people positive with Covid-19 in the ...
# 3                                                      -
#
#                                       cluster_#127  \
# Count                                            6
# 0          How to protect my family from COVID-19?
# 1                 How to protect myself on a plane
# 2                   how to protect myself from it
# 3      How can I protect myself from the covid-19?
#
#                                          cluster_#128  \
# Count                                               2
# 0                  How many days should I isolate for
# 1      How many days does it take to see the symptoms
# 2                                                   -
# 3                                                   -
#
#                     cluster_#129                      cluster_#130  \
# Count                          2                                 3
# 0      What COVID-19 stands for?     When should I visit a doctor?
# 1      COVID-19 stands for what?   When should I contact a doctor?
# 2                              -  Do I need to be seen by a doctor
# 3                              -                                 -
#
#                                             cluster_#131  \
# Count                                                  2
# 0      From the infected worldwide population what is...
# 1      From the infected worldwide population what wi...
# 2                                                      -
# 3                                                      -
#
#                                             cluster_#132  \
# Count                                                  3
# 0      Does a throat feel itchy or really sore and a ...
# 1                       Is itchy throat sign of covid 19
# 2      I am feeling itchy around my body. Is it a sym...
# 3                                                      -
#
#                                    cluster_#133  \
# Count                                         2
# 0             When will it be ok to go outside?
# 1      Is it ok to go outside to get fresh air?
# 2                                             -
# 3                                             -
#
#                             cluster_#134
# Count                                  3
# 0      Can the Covid survive in the air?
# 1                 Is COVID-19 air-borne?
# 2       Does covid transfer through air?
# 3                                      -
#
# [5 rows x 135 columns]

# %%
visual.to_csv("output/clusters_ahc_1.5DT_230lsa.csv")

# %%
.to_csv("output/clusters_15KMeans_lsa.csv")

# %%
for col in dataset.columns[dataset.columns.str.contains("embedding_")]:
    for n in range(5,20):
        clustering = AgglomerativeClustering(n_clusters=n).fit(X)
        dataset[f"{n}ahc_{col.replace('embedding_','')}lda"] = clustering.labels_
#         dataset.sort_values("ahc_label")[["question","ahc_label"]].to_csv(f"output/ahc_clustered_n{n}.csv")

# %%
dataset.sort_values("13ahc_5nlda")[["question","13ahc_5nlda"]]

# %%
dataset.columns[dataset.columns.str.contains("10ahc")]
